# %% [markdown]
# # Stock and ETF History Download

# %%
#Code borrowed from https://www.kaggle.com/code/jacksoncrow/download-nasdaq-historical-data/notebook

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import os, contextlib, shutil
from os.path import isfile, join

# %% [markdown]
# ## Download all NASDAQ traded symbols

# %%
#Create symbol database using NASDAQ trading data
data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()
print('Total number of symbols traded = {}'.format(len(symbols)))
# Out:
# Total number of symbols traded = 11207

# %%
data.head()
# Out:
#   Nasdaq Traded Symbol                                   Security Name  \
# 0             Y      A         Agilent Technologies, Inc. Common Stock
# 1             Y     AA                 Alcoa Corporation Common Stock
# 2             Y    AAA  Alternative Access First Priority CLO Bond ETF
# 3             Y   AAAU          Goldman Sachs Physical Gold ETF Shares
# 4             Y  AACBU              Artius II Acquisition Inc. - Units
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Z                   Y           100.0          N
# 4                Q               G   N           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# 1              NaN         AA            AA          N
# 2              NaN        AAA           AAA          N
# 3              NaN       AAAU          AAAU          N
# 4                N        NaN         AACBU          N

# %% [markdown]
# ## Download Historical Data

# %%
offset = 0
limit = 3000 #Prevents getting rate limited
period = 'max' #Data timeline period

# %%
# %%time

limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)
# force silencing of verbose API
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in range(offset, end):
            s = symbols[i]
            data = yf.download(s, period=period, progress = False)
            if len(data.index) == 0:
                continue
        
            is_valid[i] = True
            data.to_csv('hist/{}.csv'.format(s))

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
# 1 Failed download:
# ['AACT=']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ABLLW']: YFInvalidPeriodError("ABLLW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ABPWW']: YFInvalidPeriodError("ABPWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ABR-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ABR-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ABR-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ABVEW']: YFInvalidPeriodError("ABVEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ACHR+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ACONW']: YFInvalidPeriodError("ACONW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ACP-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ACR-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ACR-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ADC-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ADNWW']: YFInvalidPeriodError("ADNWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ADSEW']: YFInvalidPeriodError("ADSEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AENTW']: YFInvalidPeriodError("AENTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AEVAW']: YFInvalidPeriodError("AEVAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AFRIW']: YFInvalidPeriodError("AFRIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AGM-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AGM-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AGM-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AGM-G']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AGM.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHH-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHL-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHL-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHL-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHT-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHT-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHT-G']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHT-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AHT-I']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AIMAW']: YFInvalidPeriodError("AIMAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AIRJW']: YFInvalidPeriodError("AIRJW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AISPW']: YFInvalidPeriodError("AISPW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AITRR']: YFInvalidPeriodError("AITRR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AKO.B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALB-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALCYW']: YFInvalidPeriodError("ALCYW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ALDFW']: YFInvalidPeriodError("ALDFW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ALL-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALL-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALL-I']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALL-J']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALTG-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALUR+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ALVOW']: YFInvalidPeriodError("ALVOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AMBI+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AMBP+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AMH-G']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AMH-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AMODW']: YFInvalidPeriodError("AMODW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AMPX+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ANG-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ANG-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ANGHW']: YFInvalidPeriodError("ANGHW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ANNAW']: YFInvalidPeriodError("ANNAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ANSCW']: YFInvalidPeriodError("ANSCW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AP+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['APCXW']: YFInvalidPeriodError("APCXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['APO-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['APUS']: YFInvalidPeriodError("APUS: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AQUNR']: YFInvalidPeriodError("AQUNR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ARES-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ARGO-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ARR-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ASB-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ASB-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ASBPW']: YFInvalidPeriodError("ASBPW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ASTLW']: YFInvalidPeriodError("ASTLW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ATCO-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATCO-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATH-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATH-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATH-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATH-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATH-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ATMCW']: YFInvalidPeriodError("ATMCW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ATMVR']: YFInvalidPeriodError("ATMVR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ATNFW']: YFInvalidPeriodError("ATNFW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AUB-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AUUDW']: YFInvalidPeriodError("AUUDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AVPTW']: YFInvalidPeriodError("AVPTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['AXS-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BA-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-K']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-L']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-M']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-N']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-O']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-P']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-Q']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAC-S']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BACQR']: YFInvalidPeriodError("BACQR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BAERW']: YFInvalidPeriodError("BAERW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BANC-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BARK+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BAYAR']: YFInvalidPeriodError("BAYAR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BBAI+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BC-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BC-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BCGWW']: YFInvalidPeriodError("BCGWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BCV-A']: YFInvalidPeriodError("BCV-A: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BDMDW']: YFInvalidPeriodError("BDMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BEATW']: YFInvalidPeriodError("BEATW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BENFW']: YFInvalidPeriodError("BENFW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BEP-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BF.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 1926-03-30 -> 2025-03-05)')
#
# 1 Failed download:
# ['BFLY+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BFRIW']: YFInvalidPeriodError("BFRIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BFS-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BFS-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BH.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BHR-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BHR-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BIAFW']: YFInvalidPeriodError("BIAFW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BIO.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 1926-03-30 -> 2025-03-05)')
#
# 1 Failed download:
# ['BIP-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BIP-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BKHAR']: YFInvalidPeriodError("BKHAR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BKKT+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BKSY+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BLDEW']: YFInvalidPeriodError("BLDEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BML-G']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BML-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BML-J']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BML-L']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BNAIW']: YFInvalidPeriodError("BNAIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BNIXR']: YFInvalidPeriodError("BNIXR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BNIXW']: YFInvalidPeriodError("BNIXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BNZIW']: YFInvalidPeriodError("BNZIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BOH-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BOH-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BOWNR']: YFInvalidPeriodError("BOWNR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BRK.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BRLSW']: YFInvalidPeriodError("BRLSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BSIIW']: YFInvalidPeriodError("BSIIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BSLKW']: YFInvalidPeriodError("BSLKW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BTBDW']: YFInvalidPeriodError("BTBDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BTCTW']: YFInvalidPeriodError("BTCTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BTMWW']: YFInvalidPeriodError("BTMWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BUJAR']: YFInvalidPeriodError("BUJAR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BUJAW']: YFInvalidPeriodError("BUJAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BW-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['BZAIW']: YFInvalidPeriodError("BZAIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['BZFDW']: YFInvalidPeriodError("BZFDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['C-N']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CADE-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CAPTW']: YFInvalidPeriodError("CAPTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CCIRW']: YFInvalidPeriodError("CCIRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CCIXW']: YFInvalidPeriodError("CCIXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CDIOW']: YFInvalidPeriodError("CDIOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CDR-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CDR-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CDROW']: YFInvalidPeriodError("CDROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CDTTW']: YFInvalidPeriodError("CDTTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CEADW']: YFInvalidPeriodError("CEADW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CELG^']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CELUW']: YFInvalidPeriodError("CELUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CEROW']: YFInvalidPeriodError("CEROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CFG-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CFG-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CFR-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CGBSW']: YFInvalidPeriodError("CGBSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CGNT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGNX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGON']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGRO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGSD']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGSM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGTL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGTX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGUI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGUS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGV']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGW']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CGXU']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHAR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHARR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHARU']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHAT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHAU']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHCI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHCO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHCT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHD']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHDN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHE']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHEB']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHEB=']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHEB+']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHEF']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHEK']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHGG']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHGX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHH']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHIQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHKP']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHMG']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHMI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHMI-A']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHMI-B']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHNR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHPS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHPT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHRD']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHRO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHRS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHRW']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHSCL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHSCM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHSCN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHSCO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHSCP']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHSN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHTR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHW']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHWY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CHY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIB']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIBR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CICB']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIEN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIF']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIFR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIFRW']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIG']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIG.C']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIGI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CII']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIK']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIM-A']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIM-B']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIM-C']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIM-D']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIMN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIMO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CINF']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CING']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CINGW']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CINT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIO-A']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CION']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CISO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CISS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIVB']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIVI']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CIX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CJET']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CJMB']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CKPT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CKX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CLAR']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CLB']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CLBK']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 1 Failed download:
# ['CLBR=']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CLBR+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CLDT-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CLNNW']: YFInvalidPeriodError("CLNNW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CLRCR']: YFInvalidPeriodError("CLRCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CLRCW']: YFInvalidPeriodError("CLRCW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CLSKW']: YFInvalidPeriodError("CLSKW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CMPOW']: YFInvalidPeriodError("CMPOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CMRE-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CMRE-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CMRE-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CMS-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CMS-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CNCKW']: YFInvalidPeriodError("CNCKW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CNO-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COCHW']: YFInvalidPeriodError("COCHW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CODI-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CODI-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CODI-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COEPW']: YFInvalidPeriodError("COEPW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['COF-I']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COF-J']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COF-K']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COF-L']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COF-N']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['COOTW']: YFInvalidPeriodError("COOTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CORZW']: YFInvalidPeriodError("CORZW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CORZZ']: YFInvalidPeriodError("CORZZ: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CRD.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CRD.B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CRESW']: YFInvalidPeriodError("CRESW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CREVW']: YFInvalidPeriodError("CREVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CRGOW']: YFInvalidPeriodError("CRGOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CRMLW']: YFInvalidPeriodError("CRMLW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CSLRW']: YFInvalidPeriodError("CSLRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CTA-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CTA-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CTCXW']: YFInvalidPeriodError("CTCXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CTO-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CUBI-E']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CUBI-F']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CUBWW']: YFInvalidPeriodError("CUBWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CURIW']: YFInvalidPeriodError("CURIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CVE+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CWEN.A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['CXAIW']: YFInvalidPeriodError("CXAIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['CYCUW']: YFInvalidPeriodError("CYCUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DAVEW']: YFInvalidPeriodError("DAVEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DBRG-H']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DBRG-I']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DBRG-J']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DC+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DECAW']: YFInvalidPeriodError("DECAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DFLIW']: YFInvalidPeriodError("DFLIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DHAIW']: YFInvalidPeriodError("DHAIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DHCNL']: YFInvalidPeriodError("DHCNL: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DISTR']: YFInvalidPeriodError("DISTR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DLNG-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DLNG-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DLR-J']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DLR-K']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DLR-L']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DMAAR']: YFInvalidPeriodError("DMAAR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DMYY=']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DMYY+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DRH-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DRMAW']: YFInvalidPeriodError("DRMAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DSX-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DSX+']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DSYWW']: YFInvalidPeriodError("DSYWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DTSQR']: YFInvalidPeriodError("DTSQR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DTSTW']: YFInvalidPeriodError("DTSTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DUK-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DX-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['DYCQR']: YFInvalidPeriodError("DYCQR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['EBR.B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ECC-D']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ECDAW']: YFInvalidPeriodError("ECDAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['ECF-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['ECXWW']: YFInvalidPeriodError("ECXWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['EDBLW']: YFInvalidPeriodError("EDBLW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
#
# 1 Failed download:
# ['EFC-A']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['EFC-B']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['EFC-C']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['EFC-D']: YFTzMissingError('possibly delisted; no timezone found')
# Total number of valid symbols downloaded = 2620
# CPU times: user 3min 17s, sys: 23.4 s, total: 3min 40s
# Wall time: 22min 29s

# %%
#Export data to csv
valid_data = data_clean[is_valid]
valid_data.to_csv('symbols_valid_meta.csv', index=False)

# %% [markdown]
# ## Seperate ETFs and Stocks

# %%
#Label if symbols are ETFs or not
etfs = valid_data[valid_data['ETF'] == 'Y']['NASDAQ Symbol'].tolist()
stocks = valid_data[valid_data['ETF'] == 'N']['NASDAQ Symbol'].tolist()

# %%
#Seperate ETFs and Stocks data into seperate folders
def move_symbols(symbols, dest):
    for s in symbols:
        filename = '{}.csv'.format(s)
        shutil.move(join('hist', filename), join(dest, filename))
        
move_symbols(etfs, "etfs")
move_symbols(stocks, "stocks")
